# %% [markdown]
# # 02 — Marker QC & seizure intervals (ds003029)
#
# Mục tiêu:
# - Kiểm tra consistency của seizure markers trong `*_events.tsv`
# - Tạo bảng intervals an toàn cho labeling (multi-seizure / pairing)
#
# Đầu vào:
# - `eda_outputs/ds003029_run_summary.csv` (từ notebook 01)
#
# Đầu ra (trong `eda_outputs/`):
# - `ds003029_marker_qc_by_run.csv`
# - `ds003029_seizure_intervals_by_run.csv`
# - `ds003029_trial_type_*_vocab.csv`

# %%
from __future__ import annotations

import sys
from pathlib import Path

import pandas as pd

ws = Path.cwd().resolve()
src_dir = ws / 'src'
if not src_dir.exists() and (ws.parent / 'src').exists():
    ws = ws.parent
src_dir = (ws / 'src').resolve()
sys.path.insert(0, str(src_dir))

from ds003029_eda.paths import get_paths
from ds003029_eda.marker_qc import build_marker_qc, export_marker_qc

paths = get_paths()
run_summary_csv = paths.outputs_dir / 'ds003029_run_summary.csv'
assert run_summary_csv.exists(), f'Missing {run_summary_csv}. Run notebook 01 first.'

run_summary = pd.read_csv(run_summary_csv)
events_paths = run_summary[['base','events_tsv']].copy() if 'events_tsv' in run_summary.columns else run_summary[['base']].assign(events_tsv='')
events_paths = events_paths[events_paths['events_tsv'].astype(str).str.len() > 0].copy()
print('runs in run_summary:', len(run_summary))
print('runs with events.tsv:', len(events_paths))
# Out:
# runs in run_summary: 106
# runs with events.tsv: 106

# %%
outputs = build_marker_qc(events_paths)
export_marker_qc(paths.outputs_dir, outputs)

per_run = outputs.per_run
intervals = outputs.intervals

print('events.tsv readable:', int(per_run['events_exists'].sum()))
ok = per_run[per_run['events_exists'] == True]
if len(ok) > 0:
    print('runs with >=1 onset:', int((ok['n_onset_markers'] > 0).sum()))
    print('runs with >=1 offset:', int((ok['n_offset_markers'] > 0).sum()))
    print('runs with paired intervals >=1:', int((ok['n_intervals_paired'] > 0).sum()))
    print('multi-seizure candidates:', int(ok['multi_seizure_candidate'].sum()))
    print('has unpaired onset:', int(ok['has_unpaired_onset'].sum()))
    print('has orphan offset:', int(ok['has_orphan_offset'].sum()))

display(per_run.head())
display(intervals.head())

print('Wrote:', (paths.outputs_dir / 'ds003029_marker_qc_by_run.csv').resolve())
print('Wrote:', (paths.outputs_dir / 'ds003029_seizure_intervals_by_run.csv').resolve())
# Out:
# events.tsv readable: 106
# runs with >=1 onset: 103
# runs with >=1 offset: 78
# runs with paired intervals >=1: 78
# multi-seizure candidates: 16
# has unpaired onset: 34
# has orphan offset: 1
#                                                 base  \
# 0  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 1  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 2  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 4  /mnt/c/Users/DELL/EEG/ds003029/sub-jh102/ses-p...
#
#                                           events_tsv  events_exists  \
# 0  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...           True
# 1  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...           True
# 2  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...           True
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...           True
# 4  /mnt/c/Users/DELL/EEG/ds003029/sub-jh102/ses-p...           True
#
#    n_trial_rows  n_unique_trial_type  n_onset_markers  n_offset_markers  \
# 0            21                   21                1                 1
# 1            26                   26                1                 1
# 2            19                   19                1                 1
# 3            20                   20                1                 1
# 4            79                   78                3                 1
#
#    n_intervals_paired  multi_seizure_candidate  has_unpaired_onset  \
# 0                   1                    False               False
# 1                   1                    False               False
# 2                   1                    False               False
# 3                   1                    False               False
# 4                   1                     True                True
#
#    has_orphan_offset  min_onset_s  max_offset_s
# 0              False       58.950        79.875
# 1              False       66.825       275.850
# 2              False       58.950        79.875
# 3              False       58.950        84.825
# 4              False       54.834       333.944
#                                                 base  \
# 0  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 1  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 2  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 4  /mnt/c/Users/DELL/EEG/ds003029/sub-jh102/ses-p...
#
#                                           events_tsv  onset_s  offset_s  \
# 0  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...   58.950    79.875
# 1  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...   66.825   275.850
# 2  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...   58.950    79.875
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...   58.950    84.825
# 4  /mnt/c/Users/DELL/EEG/ds003029/sub-jh102/ses-p...   54.834   333.944
#
#    duration_s     onset_trial_type     offset_trial_type
# 0      20.925  SZ EVENT # (EEG SZ)  Z ELECTROGRAPHIC END
# 1     209.025  SZ EVENT # (EEG SZ)  Z ELECTROGRAPHIC END
# 2      20.925  SZ EVENT # (EEG SZ)  Z ELECTROGRAPHIC END
# 3      25.875  SZ EVENT # (EEG SZ)  Z ELECTROGRAPHIC END
# 4     279.110       * poss r onset  Z ELECTROGRAPHIC END
# Wrote: /mnt/c/Users/DELL/eda_outputs/ds003029_marker_qc_by_run.csv
# Wrote: /mnt/c/Users/DELL/eda_outputs/ds003029_seizure_intervals_by_run.csv
