# %% [markdown]
# # 01 — Metadata inventory & run_summary (ds003029)
#
# Mục tiêu:
# - Quét toàn bộ metadata BIDS (không cần tải `*.eeg`)
# - Tạo `eda_outputs/ds003029_run_summary.csv` + `eda_outputs/ds003029_event_vocab.csv`
#
# Đầu vào:
# - Dataset tại `EEG/ds003029` (BIDS iEEG)
#
# Đầu ra:
# - `eda_outputs/ds003029_run_summary.csv`
# - `eda_outputs/ds003029_event_vocab.csv`

# %%
from __future__ import annotations

import sys
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# Make src/ importable (works from repo root or notebooks/)
ws = Path.cwd().resolve()
src_dir = ws / 'src'
if not src_dir.exists() and (ws.parent / 'src').exists():
    ws = ws.parent
src_dir = (ws / 'src').resolve()
sys.path.insert(0, str(src_dir))

from ds003029_eda.paths import get_paths
from ds003029_eda.run_summary import build_run_summary, export_run_summary

paths = get_paths()
paths.outputs_dir.mkdir(exist_ok=True)
print('Workspace:', paths.workspace)
print('Dataset root:', paths.dataset_root)
print('Outputs:', paths.outputs_dir)
# Out:
# Workspace: /mnt/c/Users/DELL
# Dataset root: /mnt/c/Users/DELL/EEG/ds003029
# Outputs: /mnt/c/Users/DELL/eda_outputs

# %%
result = build_run_summary(paths.dataset_root)
run_summary = result.run_summary
event_vocab = result.event_vocab

print('runs:', len(run_summary))
print('subjects:', run_summary['subject'].nunique() if 'subject' in run_summary.columns else 'n/a')
print('runs with onset:', int(run_summary['has_onset'].sum()))
print('runs with onset+offset:', int((run_summary['has_onset'] & run_summary['has_offset']).sum()))
print('runs with eeg content present (heuristic):', int(run_summary['eeg_content_present'].sum()))

display(run_summary.head())
display(event_vocab.head(30))

export_run_summary(paths.outputs_dir, result)
print('Wrote:', (paths.outputs_dir / 'ds003029_run_summary.csv').resolve())
print('Wrote:', (paths.outputs_dir / 'ds003029_event_vocab.csv').resolve())
# Out:
# runs: 106
# subjects: 35
# runs with onset: 103
# runs with onset+offset: 78
# runs with eeg content present (heuristic): 15
#   subject     session   task   acq run  \
# 0   jh101  presurgery  ictal  ecog  01
# 1   jh101  presurgery  ictal  ecog  02
# 2   jh101  presurgery  ictal  ecog  03
# 3   jh101  presurgery  ictal  ecog  04
# 4   jh102  presurgery  ictal  ecog  01
#
#                                                 base  \
# 0  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 1  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 2  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 4  /mnt/c/Users/DELL/EEG/ds003029/sub-jh102/ses-p...
#
#                                                 vhdr  \
# 0  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 1  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 2  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 4  /mnt/c/Users/DELL/EEG/ds003029/sub-jh102/ses-p...
#
#                                                 vmrk  \
# 0
# 1
# 2
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 4
#
#                                                  eeg  \
# 0
# 1
# 2
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...
# 4
#
#                                         channels_tsv  ... line_freq  \
# 0  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...  ...      60.0
# 1  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...  ...      60.0
# 2  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...  ...      60.0
# 3  /mnt/c/Users/DELL/EEG/ds003029/sub-jh101/ses-p...  ...      60.0
# 4  /mnt/c/Users/DELL/EEG/ds003029/sub-jh102/ses-p...  ...      60.0
#
#   n_channels  n_bad  has_onset  has_offset  seizure_onset_s  seizure_offset_s  \
# 0        135     26       True        True           58.950            79.875
# 1        135     26       True        True           66.825           275.850
# 2        135     26       True        True           58.950            79.875
# 3        135     26       True        True           58.950            84.825
# 4        123      8       True        True           54.834           333.944
#
#    seizure_duration_s  eeg_size_bytes  eeg_content_present
# 0              20.925             NaN                False
# 1             209.025             NaN                False
# 2              20.925             NaN                False
# 3              25.875      82620000.0                 True
# 4             279.110             NaN                False
#
# [5 rows x 23 columns]
#                        trial_type  count
# 0                       +0.000000     75
# 1                       A1+A2 OFF     69
# 2                          offset     32
# 3                        Schedule     29
# 4                        sz onset     27
# 5                       sz offset     26
# 6              SZ EVENT # (PB SZ)     19
# 7                           onset     19
# 8                      +59.000000     17
# 9                      +62.000000     17
# 10     Segment: REC START REC EEG     17
# 11                     +60.000000     17
# 12                        MARK ON     17
# 13                     +61.000000     11
# 14                     +72.000000     11
# 15                     +66.000000     11
# 16                     +65.000000     11
# 17                     +68.000000     10
# 18                     +77.000000     10
# 19                     +80.000000      9
# 20                     +71.000000      9
# 21                     +86.000000      9
# 22  Segment: REC START BP ALL EEG      8
# 23                     +64.000000      8
# 24           Z ELECTROGRAPHIC END      8
# 25                     +74.000000      8
# 26                     +84.000000      8
# 27                     +83.000000      7
# 28                    +101.000000      7
# 29                     +63.000000      7
# Wrote: /mnt/c/Users/DELL/eda_outputs/ds003029_run_summary.csv
# Wrote: /mnt/c/Users/DELL/eda_outputs/ds003029_event_vocab.csv

# %% [markdown]
# ## Quick EDA plots (sanity)
# Các plot dưới đây là để sanity-check: phân bố `sfreq`, `n_channels`, và coverage seizure markers.

# %%
rs = run_summary.copy()
fig, axes = plt.subplots(1, 3, figsize=(14, 4))

axes[0].hist(rs['sfreq'].dropna(), bins=20)
axes[0].set_title('Sampling frequency (sfreq)')
axes[0].set_xlabel('Hz')

axes[1].hist(rs['n_channels'].dropna(), bins=20)
axes[1].set_title('Channel count (n_channels)')
axes[1].set_xlabel('#channels')

counts = pd.Series({
    'total': len(rs),
    'has_onset': int(rs['has_onset'].sum()),
    'has_onset+offset': int((rs['has_onset'] & rs['has_offset']).sum()),
    'eeg_content_present': int(rs['eeg_content_present'].sum()),
})
axes[2].bar(counts.index, counts.values)
axes[2].set_title('Coverage')
axes[2].tick_params(axis='x', rotation=20)

plt.tight_layout(); plt.show()
